# %%
from ultralytics import YOLO

model = YOLO('helpers/models/best320x192v2.pt')

# %%
image = cv2.imread('your_image.jpg')

# %%
results = model.predict(image, conf=0.9, show=False)
# Out:
# image 1/1 C:\Users\DEVIN PHAM\Documents\UCSD\Winter 2024\DSC 190\dsc190-track-detection\test_image.jpg: 192x320 1 primary road, 83.8ms
# Speed: 1.0ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 192, 320)

# %%
results[0].boxes.xyxy
# Out:
# tensor([[4.8930e-01, 5.2052e+01, 6.6983e+02, 3.7302e+02]])

# %%
results[0].boxes.conf
# Out:
# tensor([0.9177])

# %%
results[0].boxes.cls
# Out:
# tensor([0.])

# %%
results[0].masks.xy
# Out:
# [array([[       10.5,        53.6],
#         [        8.4,        55.7],
#         [        8.4,       158.6],
#         [       10.5,       160.7],
#         [       10.5,       175.4],
#         [       12.6,       177.5],
#         [       14.7,       175.4],
#         [       14.7,       171.2],
#         [       16.8,       169.1],
#         [       16.8,       164.9],
#         [       18.9,       162.8],
#         [       18.9,       160.7],
#         [         21,       158.6],
#         [         21,         146],
#         [       23.1,       143.9],
#         [       23.1,       139.7],
#         [       25.2,       137.6],
#         [       25.2,       135.5],
#         [       29.4,       131.3],
#         [       33.6,       131.3],
#         [       35.7,       129.2],
#         [       46.2,       139.7],
#         [       46.2,       141.8],
#         [       60.9,       156.5],
#         [       67.2,       156.5],
#         [       69.3,       158.6],
# ...
